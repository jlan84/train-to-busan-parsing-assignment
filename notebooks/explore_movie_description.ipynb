# %% [markdown]
# ## Explore movie description
# This notebook is used to initially look at the text data and make some plots and figures to help understand what's in it.
#
# To execute each cell, click on it and then type `shift-enter`.  You can insert
# another code or markdown cell above or below any cell by clicking on `Insert` in the above menu bar.

# %%
# first a function to read in a file given a filename

def read_the_file(fname):
    '''Reads the filename - should have a .txt extension.

       Returns a text string containing the entire description.
    ''' 
    f = open(fname, 'r')
    textstring = f.read()
    return textstring

# %%
# relative path to description
path_including_filename = "../data/train_to_busan_description.txt"

text = read_the_file(path_including_filename)

# %%
text
# Out:
# 'Seok-woo, a divorced fund manager, is a workaholic and absentee father to his \nyoung daughter, Su-an. For her birthday the next day, she wishes for her father\nto take her to Busan to see her mother. They board the KTX at Seoul Station. \nOthers on the same train are tough working-class husband Sang-hwa and his \npregnant wife Seong-kyeong, a high school baseball team, rich-yet-egotistical \nCOO Yon-suk, elderly sisters In-gil and Jon-gil, and a homeless man who is \nexperiencing post-traumatic stress disorder.  As the train departs, a convulsing\nyoung woman boards the train with a bite wound on her leg. The woman soon becomes\na zombie and attacks a train attendant, who then also turns into a zombie. The \ninfection quickly spreads throughout the train. Baseball player Yong-guk, a girl\nnamed Jin-hee who has a crush on him, and several passengers manage to escape to \nanother car. News broadcasts report zombie outbreaks throughout the country. The \ntrain stops at Daejeon, but the surviving passengers find that the city has also \nbeen overrun, and they hastily retreat back to the train, splitting up into \ndifferent train cars in the chaos. The conductor restarts the train to head to \nBusan, where a successful quarantine zone has reportedly been established.\nSeok-woo, Sang-hwa, and Yong-guk fight their way to where Su-an, In-gil, and \nSeong-kyeong are hiding, and together they struggle through the zombie horde to \nthe front train car, where the other passengers are sheltered. However, at the \ninstigation of Yon-suk, the passengers block the survivors from entering, fearing \nthat they are infected. Sang-hwa and In-gil sacrifice themselves to give the \nothers time to force open the door and enter the car. Yon-suk demands that the \nnewcomers isolate themselves in the vestibule, and the others follow his lead. \nWhen Jong-gil deliberately opens the door to the zombies to be with her zombified \nsister In-gil, the zombies kill the rest of the passengers, leaving Seok-woo, \nSu-an and Seong-kyeong safe, as they are in the vestibule. Yon-suk and the train \nattendant escape the onslaught by hiding in the bathroom.\nA blocked track at East Daegu train station forces the survivors to stop and \nsearch for another train. In the process, Seok-woo, Seong-kyeong, Su-an, and \nthe homeless man are separated from Yong-guk and Jin-hee. Yon-suk escapes after \npushing the train attendant to be killed by the zombies, then does the same with \nJin-hee. Heartbroken, Yong-guk stays with Jin-hee and is soon bitten by her. \nThe train conductor starts a locomotive on another track but is also killed by \nzombies while trying to save Yon-suk. The homeless man sacrifices himself to \nlet Su-an and Seong-kyeong escape with Seok-woo into the train the conductor had \nactivated. They encounter Yon-suk in the engine room, on the verge of turning \ninto a zombie, having been bitten when the train conductor saved him. Seok-woo \nfights him off, but is himself bitten. He puts Su-an and Seong-kyeong inside \nthe engine room and shares his last words with his daughter before moving outside. \nAs he zombifies, he thinks of the first time he held his daughter in his arms \nand throws himself off the locomotive with a smile.\nSu-an and Seong-kyeong get off at Busan and begin walking through a train tunnel. \nOn the other side of the tunnel are soldiers stationed to defend the perimeter \nagainst zombies. Unable to see the new arrivals clearly, the soldiers at the \ncheckpoint are instructed to shoot them. However, the soldiers then hear singing, \nwhich makes them realize the newcomers are human: it is Su-an, tearfully singing \nthe song that she had wanted to perform for her father at the beginning of the \nfilm, now singing it to honor his sacrifice.\n'

# %%
# the text has \n (newlines) in it.  If we print it, the newlines will render
print(text)
# Out:
# Seok-woo, a divorced fund manager, is a workaholic and absentee father to his
# young daughter, Su-an. For her birthday the next day, she wishes for her father
# to take her to Busan to see her mother. They board the KTX at Seoul Station.
# Others on the same train are tough working-class husband Sang-hwa and his
# pregnant wife Seong-kyeong, a high school baseball team, rich-yet-egotistical
# COO Yon-suk, elderly sisters In-gil and Jon-gil, and a homeless man who is
# experiencing post-traumatic stress disorder.  As the train departs, a convulsing
# young woman boards the train with a bite wound on her leg. The woman soon becomes
# a zombie and attacks a train attendant, who then also turns into a zombie. The
# infection quickly spreads throughout the train. Baseball player Yong-guk, a girl
# named Jin-hee who has a crush on him, and several passengers manage to escape to
# another car. News broadcasts report zombie outbreaks throughout the country. The
# train stops at Daejeon, but the surviving passengers find that the city has also
# been overrun, and they hastily retreat back to the train, splitting up into
# different train cars in the chaos. The conductor restarts the train to head to
# Busan, where a successful quarantine zone has reportedly been established.
# Seok-woo, Sang-hwa, and Yong-guk fight their way to where Su-an, In-gil, and
# Seong-kyeong are hiding, and together they struggle through the zombie horde to
# the front train car, where the other passengers are sheltered. However, at the
# instigation of Yon-suk, the passengers block the survivors from entering, fearing
# that they are infected. Sang-hwa and In-gil sacrifice themselves to give the
# others time to force open the door and enter the car. Yon-suk demands that the
# newcomers isolate themselves in the vestibule, and the others follow his lead.
# When Jong-gil deliberately opens the door to the zombies to be with her zombified
# sister In-gil, the zombies kill the rest of the passengers, leaving Seok-woo,
# Su-an and Seong-kyeong safe, as they are in the vestibule. Yon-suk and the train
# attendant escape the onslaught by hiding in the bathroom.
# A blocked track at East Daegu train station forces the survivors to stop and
# search for another train. In the process, Seok-woo, Seong-kyeong, Su-an, and
# the homeless man are separated from Yong-guk and Jin-hee. Yon-suk escapes after
# pushing the train attendant to be killed by the zombies, then does the same with
# Jin-hee. Heartbroken, Yong-guk stays with Jin-hee and is soon bitten by her.
# The train conductor starts a locomotive on another track but is also killed by
# zombies while trying to save Yon-suk. The homeless man sacrifices himself to
# let Su-an and Seong-kyeong escape with Seok-woo into the train the conductor had
# activated. They encounter Yon-suk in the engine room, on the verge of turning
# into a zombie, having been bitten when the train conductor saved him. Seok-woo
# fights him off, but is himself bitten. He puts Su-an and Seong-kyeong inside
# the engine room and shares his last words with his daughter before moving outside.
# As he zombifies, he thinks of the first time he held his daughter in his arms
# and throws himself off the locomotive with a smile.
# Su-an and Seong-kyeong get off at Busan and begin walking through a train tunnel.
# On the other side of the tunnel are soldiers stationed to defend the perimeter
# against zombies. Unable to see the new arrivals clearly, the soldiers at the
# checkpoint are instructed to shoot them. However, the soldiers then hear singing,
# which makes them realize the newcomers are human: it is Su-an, tearfully singing
# the song that she had wanted to perform for her father at the beginning of the
# film, now singing it to honor his sacrifice.

# %% [markdown]
# ### Clean the text

# %%
# specify how many characters to show after each step (arbitrary)
nc = 160

# lowercase it
text_lc = text.lower()
text_lc[:nc]  # show first nc characters
# Out:
# 'seok-woo, a divorced fund manager, is a workaholic and absentee father to his \nyoung daughter, su-an. for her birthday the next day, she wishes for her father\nt'

# %%
# remove punctuation
from string import punctuation

text_np = ''.join([ch for ch in text_lc if ch not in punctuation])
text_np[:nc]
# Out:
# 'seokwoo a divorced fund manager is a workaholic and absentee father to his \nyoung daughter suan for her birthday the next day she wishes for her father\nto take '

# %%
# remove newline characters
text_nnl = text_np.replace('\n', ' ')
text_nnl[:nc]
# Out:
# 'seokwoo a divorced fund manager is a workaholic and absentee father to his  young daughter suan for her birthday the next day she wishes for her father to take '

# %%
# split into words
words = text_nnl.split(' ')
words
# Out:
# ['seokwoo',
#  'a',
#  'divorced',
#  'fund',
#  'manager',
#  'is',
#  'a',
#  'workaholic',
#  'and',
#  'absentee',
#  'father',
#  'to',
#  'his',
#  '',
#  'young',
#  'daughter',
#  'suan',
#  'for',
#  'her',
#  'birthday',
#  'the',
#  'next',
#  'day',
#  'she',
#  'wishes',
#  'for',
#  'her',
#  'father',
#  'to',
#  'take',
#  'her',
#  'to',
#  'busan',
#  'to',
#  'see',
#  'her',
#  'mother',
#  'they',
#  'board',
#  'the',
#  'ktx',
#  'at',
#  'seoul',
#  'station',
#  '',
#  'others',
#  'on',
#  'the',
#  'same',
#  'train',
#  'are',
#  'tough',
#  'workingclass',
#  'husband',
#  'sanghwa',
#  'and',
#  'his',
#  '',
#  'pregnant',
#  'wife',
#  'seongkyeong',
#  'a',
#  'high',
#  'school',
#  'baseball',
#  'team',
#  'richyetegotistical',
#  '',
#  'coo',
#  'yonsuk',
#  'elderly',
#  'sisters',
#  'ingil',
#  'and',
#  'jongil',
#  'and',
#  'a',
#  'homeless',
#  'man',
#  'who',
#  'is',
#  '',
#  'experiencing',
#  'posttraumatic',
#  'stress',
#  'disorder',
#  '',
#  'as',
#  'the',
#  'train',
#  'departs',
#  'a',
#  'convulsing',
#  'young',
#  'woman',
#  'boards',
#  'the',
#  'train',
#  'with',
#  'a',
#  'bite',
#  'wound',
#  'on',
#  'her',
#  'leg',
#  'the',
#  'woman',
#  'soon',
#  'becomes',
#  'a',
#  'zombie',
#  'and',
#  'attacks',
#  'a',
#  'train',
#  'attendant',
#  'who',
#  'then',
#  'also',
#  'turns',
#  'into',
#  'a',
#  'zombie',
#  'the',
#  '',
#  'infection',
#  'quickly',
#  'spreads',
#  'throughout',
#  'the',
#  'train',
#  'baseball',
#  'player',
#  'yongguk',
#  'a',
#  'girl',
#  'named',
#  'jinhee',
#  'who',
#  'has',
#  'a',
#  'crush',
#  'on',
#  'him',
#  'and',
#  'several',
#  'passengers',
#  'manage',
#  'to',
#  'escape',
#  'to',
#  '',
#  'another',
#  'car',
#  'news',
#  'broadcasts',
#  'report',
#  'zombie',
#  'outbreaks',
#  'throughout',
#  'the',
#  'country',
#  'the',
#  '',
#  'train',
#  'stops',
#  'at',
#  'daejeon',
#  'but',
#  'the',
#  'surviving',
#  'passengers',
#  'find',
#  'that',
#  'the',
#  'city',
#  'has',
#  'also',
#  '',
#  'been',
#  'overrun',
#  'and',
#  'they',
#  'hastily',
#  'retreat',
#  'back',
#  'to',
#  'the',
#  'train',
#  'splitting',
#  'up',
#  'into',
#  '',
#  'different',
#  'train',
#  'cars',
#  'in',
#  'the',
#  'chaos',
#  'the',
#  'conductor',
#  'restarts',
#  'the',
#  'train',
#  'to',
#  'head',
#  'to',
#  '',
#  'busan',
#  'where',
#  'a',
#  'successful',
#  'quarantine',
#  'zone',
#  'has',
#  'reportedly',
#  'been',
#  'established',
#  'seokwoo',
#  'sanghwa',
#  'and',
#  'yongguk',
#  'fight',
#  'their',
#  'way',
#  'to',
#  'where',
#  'suan',
#  'ingil',
#  'and',
#  '',
#  'seongkyeong',
#  'are',
#  'hiding',
#  'and',
#  'together',
#  'they',
#  'struggle',
#  'through',
#  'the',
#  'zombie',
#  'horde',
#  'to',
#  '',
#  'the',
#  'front',
#  'train',
#  'car',
#  'where',
#  'the',
#  'other',
#  'passengers',
#  'are',
#  'sheltered',
#  'however',
#  'at',
#  'the',
#  '',
#  'instigation',
#  'of',
#  'yonsuk',
#  'the',
#  'passengers',
#  'block',
#  'the',
#  'survivors',
#  'from',
#  'entering',
#  'fearing',
#  '',
#  'that',
#  'they',
#  'are',
#  'infected',
#  'sanghwa',
#  'and',
#  'ingil',
#  'sacrifice',
#  'themselves',
#  'to',
#  'give',
#  'the',
#  '',
#  'others',
#  'time',
#  'to',
#  'force',
#  'open',
#  'the',
#  'door',
#  'and',
#  'enter',
#  'the',
#  'car',
#  'yonsuk',
#  'demands',
#  'that',
#  'the',
#  '',
#  'newcomers',
#  'isolate',
#  'themselves',
#  'in',
#  'the',
#  'vestibule',
#  'and',
#  'the',
#  'others',
#  'follow',
#  'his',
#  'lead',
#  '',
#  'when',
#  'jonggil',
#  'deliberately',
#  'opens',
#  'the',
#  'door',
#  'to',
#  'the',
#  'zombies',
#  'to',
#  'be',
#  'with',
#  'her',
#  'zombified',
#  '',
#  'sister',
#  'ingil',
#  'the',
#  'zombies',
#  'kill',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'passengers',
#  'leaving',
#  'seokwoo',
#  '',
#  'suan',
#  'and',
#  'seongkyeong',
#  'safe',
#  'as',
#  'they',
#  'are',
#  'in',
#  'the',
#  'vestibule',
#  'yonsuk',
#  'and',
#  'the',
#  'train',
#  '',
#  'attendant',
#  'escape',
#  'the',
#  'onslaught',
#  'by',
#  'hiding',
#  'in',
#  'the',
#  'bathroom',
#  'a',
#  'blocked',
#  'track',
#  'at',
#  'east',
#  'daegu',
#  'train',
#  'station',
#  'forces',
#  'the',
#  'survivors',
#  'to',
#  'stop',
#  'and',
#  '',
#  'search',
#  'for',
#  'another',
#  'train',
#  'in',
#  'the',
#  'process',
#  'seokwoo',
#  'seongkyeong',
#  'suan',
#  'and',
#  '',
#  'the',
#  'homeless',
#  'man',
#  'are',
#  'separated',
#  'from',
#  'yongguk',
#  'and',
#  'jinhee',
#  'yonsuk',
#  'escapes',
#  'after',
#  '',
#  'pushing',
#  'the',
#  'train',
#  'attendant',
#  'to',
#  'be',
#  'killed',
#  'by',
#  'the',
#  'zombies',
#  'then',
#  'does',
#  'the',
#  'same',
#  'with',
#  '',
#  'jinhee',
#  'heartbroken',
#  'yongguk',
#  'stays',
#  'with',
#  'jinhee',
#  'and',
#  'is',
#  'soon',
#  'bitten',
#  'by',
#  'her',
#  '',
#  'the',
#  'train',
#  'conductor',
#  'starts',
#  'a',
#  'locomotive',
#  'on',
#  'another',
#  'track',
#  'but',
#  'is',
#  'also',
#  'killed',
#  'by',
#  '',
#  'zombies',
#  'while',
#  'trying',
#  'to',
#  'save',
#  'yonsuk',
#  'the',
#  'homeless',
#  'man',
#  'sacrifices',
#  'himself',
#  'to',
#  '',
#  'let',
#  'suan',
#  'and',
#  'seongkyeong',
#  'escape',
#  'with',
#  'seokwoo',
#  'into',
#  'the',
#  'train',
#  'the',
#  'conductor',
#  'had',
#  '',
#  'activated',
#  'they',
#  'encounter',
#  'yonsuk',
#  'in',
#  'the',
#  'engine',
#  'room',
#  'on',
#  'the',
#  'verge',
#  'of',
#  'turning',
#  '',
#  'into',
#  'a',
#  'zombie',
#  'having',
#  'been',
#  'bitten',
#  'when',
#  'the',
#  'train',
#  'conductor',
#  'saved',
#  'him',
#  'seokwoo',
#  '',
#  'fights',
#  'him',
#  'off',
#  'but',
#  'is',
#  'himself',
#  'bitten',
#  'he',
#  'puts',
#  'suan',
#  'and',
#  'seongkyeong',
#  'inside',
#  '',
#  'the',
#  'engine',
#  'room',
#  'and',
#  'shares',
#  'his',
#  'last',
#  'words',
#  'with',
#  'his',
#  'daughter',
#  'before',
#  'moving',
#  'outside',
#  '',
#  'as',
#  'he',
#  'zombifies',
#  'he',
#  'thinks',
#  'of',
#  'the',
#  'first',
#  'time',
#  'he',
#  'held',
#  'his',
#  'daughter',
#  'in',
#  'his',
#  'arms',
#  '',
#  'and',
#  'throws',
#  'himself',
#  'off',
#  'the',
#  'locomotive',
#  'with',
#  'a',
#  'smile',
#  'suan',
#  'and',
#  'seongkyeong',
#  'get',
#  'off',
#  'at',
#  'busan',
#  'and',
#  'begin',
#  'walking',
#  'through',
#  'a',
#  'train',
#  'tunnel',
#  '',
#  'on',
#  'the',
#  'other',
#  'side',
#  'of',
#  'the',
#  'tunnel',
#  'are',
#  'soldiers',
#  'stationed',
#  'to',
#  'defend',
#  'the',
#  'perimeter',
#  '',
#  'against',
#  'zombies',
#  'unable',
#  'to',
#  'see',
#  'the',
#  'new',
#  'arrivals',
#  'clearly',
#  'the',
#  'soldiers',
#  'at',
#  'the',
#  '',
#  'checkpoint',
#  'are',
#  'instructed',
#  'to',
#  'shoot',
#  'them',
#  'however',
#  'the',
#  'soldiers',
#  'then',
#  'hear',
#  'singing',
#  '',
#  'which',
#  'makes',
#  'them',
#  'realize',
#  'the',
#  'newcomers',
#  'are',
#  'human',
#  'it',
#  'is',
#  'suan',
#  'tearfully',
#  'singing',
#  '',
#  'the',
#  'song',
#  'that',
#  'she',
#  'had',
#  'wanted',
#  'to',
#  'perform',
#  'for',
#  'her',
#  'father',
#  'at',
#  'the',
#  'beginning',
#  'of',
#  'the',
#  '',
#  'film',
#  'now',
#  'singing',
#  'it',
#  'to',
#  'honor',
#  'his',
#  'sacrifice',
#  '']

# %%
# a function to help summarize the output

def print_word_stats(words):
    num_words = len(words)
    unique_words = set(words)
    num_unique_words = len(unique_words)
    print(f"The number of words in the description is {num_words}.")
    print(f"The number of unique words in the description is {num_unique_words}.")

# %%
# before removing stopswords
print_word_stats(words)
# Out:
# The number of words in the description is 655.
# The number of unique words in the description is 266.

# %%
# remove stopwords
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
stopwords = ENGLISH_STOP_WORDS

words_nsw = [word for word in words if word not in stopwords]

# %%
# after removing stopwords
print_word_stats(words_nsw)
# Out:
# The number of words in the description is 347.
# The number of unique words in the description is 199.

# %%
words_nsw
# Out:
# ['seokwoo',
#  'divorced',
#  'fund',
#  'manager',
#  'workaholic',
#  'absentee',
#  'father',
#  '',
#  'young',
#  'daughter',
#  'suan',
#  'birthday',
#  'day',
#  'wishes',
#  'father',
#  'busan',
#  'mother',
#  'board',
#  'ktx',
#  'seoul',
#  'station',
#  '',
#  'train',
#  'tough',
#  'workingclass',
#  'husband',
#  'sanghwa',
#  '',
#  'pregnant',
#  'wife',
#  'seongkyeong',
#  'high',
#  'school',
#  'baseball',
#  'team',
#  'richyetegotistical',
#  '',
#  'coo',
#  'yonsuk',
#  'elderly',
#  'sisters',
#  'ingil',
#  'jongil',
#  'homeless',
#  'man',
#  '',
#  'experiencing',
#  'posttraumatic',
#  'stress',
#  'disorder',
#  '',
#  'train',
#  'departs',
#  'convulsing',
#  'young',
#  'woman',
#  'boards',
#  'train',
#  'bite',
#  'wound',
#  'leg',
#  'woman',
#  'soon',
#  'zombie',
#  'attacks',
#  'train',
#  'attendant',
#  'turns',
#  'zombie',
#  '',
#  'infection',
#  'quickly',
#  'spreads',
#  'train',
#  'baseball',
#  'player',
#  'yongguk',
#  'girl',
#  'named',
#  'jinhee',
#  'crush',
#  'passengers',
#  'manage',
#  'escape',
#  '',
#  'car',
#  'news',
#  'broadcasts',
#  'report',
#  'zombie',
#  'outbreaks',
#  'country',
#  '',
#  'train',
#  'stops',
#  'daejeon',
#  'surviving',
#  'passengers',
#  'city',
#  '',
#  'overrun',
#  'hastily',
#  'retreat',
#  'train',
#  'splitting',
#  '',
#  'different',
#  'train',
#  'cars',
#  'chaos',
#  'conductor',
#  'restarts',
#  'train',
#  'head',
#  '',
#  'busan',
#  'successful',
#  'quarantine',
#  'zone',
#  'reportedly',
#  'established',
#  'seokwoo',
#  'sanghwa',
#  'yongguk',
#  'fight',
#  'way',
#  'suan',
#  'ingil',
#  '',
#  'seongkyeong',
#  'hiding',
#  'struggle',
#  'zombie',
#  'horde',
#  '',
#  'train',
#  'car',
#  'passengers',
#  'sheltered',
#  '',
#  'instigation',
#  'yonsuk',
#  'passengers',
#  'block',
#  'survivors',
#  'entering',
#  'fearing',
#  '',
#  'infected',
#  'sanghwa',
#  'ingil',
#  'sacrifice',
#  '',
#  'time',
#  'force',
#  'open',
#  'door',
#  'enter',
#  'car',
#  'yonsuk',
#  'demands',
#  '',
#  'newcomers',
#  'isolate',
#  'vestibule',
#  'follow',
#  'lead',
#  '',
#  'jonggil',
#  'deliberately',
#  'opens',
#  'door',
#  'zombies',
#  'zombified',
#  '',
#  'sister',
#  'ingil',
#  'zombies',
#  'kill',
#  'rest',
#  'passengers',
#  'leaving',
#  'seokwoo',
#  '',
#  'suan',
#  'seongkyeong',
#  'safe',
#  'vestibule',
#  'yonsuk',
#  'train',
#  '',
#  'attendant',
#  'escape',
#  'onslaught',
#  'hiding',
#  'bathroom',
#  'blocked',
#  'track',
#  'east',
#  'daegu',
#  'train',
#  'station',
#  'forces',
#  'survivors',
#  'stop',
#  '',
#  'search',
#  'train',
#  'process',
#  'seokwoo',
#  'seongkyeong',
#  'suan',
#  '',
#  'homeless',
#  'man',
#  'separated',
#  'yongguk',
#  'jinhee',
#  'yonsuk',
#  'escapes',
#  '',
#  'pushing',
#  'train',
#  'attendant',
#  'killed',
#  'zombies',
#  'does',
#  '',
#  'jinhee',
#  'heartbroken',
#  'yongguk',
#  'stays',
#  'jinhee',
#  'soon',
#  'bitten',
#  '',
#  'train',
#  'conductor',
#  'starts',
#  'locomotive',
#  'track',
#  'killed',
#  '',
#  'zombies',
#  'trying',
#  'save',
#  'yonsuk',
#  'homeless',
#  'man',
#  'sacrifices',
#  '',
#  'let',
#  'suan',
#  'seongkyeong',
#  'escape',
#  'seokwoo',
#  'train',
#  'conductor',
#  '',
#  'activated',
#  'encounter',
#  'yonsuk',
#  'engine',
#  'room',
#  'verge',
#  'turning',
#  '',
#  'zombie',
#  'having',
#  'bitten',
#  'train',
#  'conductor',
#  'saved',
#  'seokwoo',
#  '',
#  'fights',
#  'bitten',
#  'puts',
#  'suan',
#  'seongkyeong',
#  'inside',
#  '',
#  'engine',
#  'room',
#  'shares',
#  'words',
#  'daughter',
#  'moving',
#  'outside',
#  '',
#  'zombifies',
#  'thinks',
#  'time',
#  'held',
#  'daughter',
#  'arms',
#  '',
#  'throws',
#  'locomotive',
#  'smile',
#  'suan',
#  'seongkyeong',
#  'busan',
#  'begin',
#  'walking',
#  'train',
#  'tunnel',
#  '',
#  'tunnel',
#  'soldiers',
#  'stationed',
#  'defend',
#  'perimeter',
#  '',
#  'zombies',
#  'unable',
#  'new',
#  'arrivals',
#  'clearly',
#  'soldiers',
#  '',
#  'checkpoint',
#  'instructed',
#  'shoot',
#  'soldiers',
#  'hear',
#  'singing',
#  '',
#  'makes',
#  'realize',
#  'newcomers',
#  'human',
#  'suan',
#  'tearfully',
#  'singing',
#  '',
#  'song',
#  'wanted',
#  'perform',
#  'father',
#  'beginning',
#  '',
#  'film',
#  'singing',
#  'honor',
#  'sacrifice',
#  '']

# %%
# it looks like '' occurs as a word in many places - remove it
words_cleaned = [word for word in words_nsw if word is not '']

# %%
words_cleaned
# Out:
# ['seokwoo',
#  'divorced',
#  'fund',
#  'manager',
#  'workaholic',
#  'absentee',
#  'father',
#  'young',
#  'daughter',
#  'suan',
#  'birthday',
#  'day',
#  'wishes',
#  'father',
#  'busan',
#  'mother',
#  'board',
#  'ktx',
#  'seoul',
#  'station',
#  'train',
#  'tough',
#  'workingclass',
#  'husband',
#  'sanghwa',
#  'pregnant',
#  'wife',
#  'seongkyeong',
#  'high',
#  'school',
#  'baseball',
#  'team',
#  'richyetegotistical',
#  'coo',
#  'yonsuk',
#  'elderly',
#  'sisters',
#  'ingil',
#  'jongil',
#  'homeless',
#  'man',
#  'experiencing',
#  'posttraumatic',
#  'stress',
#  'disorder',
#  'train',
#  'departs',
#  'convulsing',
#  'young',
#  'woman',
#  'boards',
#  'train',
#  'bite',
#  'wound',
#  'leg',
#  'woman',
#  'soon',
#  'zombie',
#  'attacks',
#  'train',
#  'attendant',
#  'turns',
#  'zombie',
#  'infection',
#  'quickly',
#  'spreads',
#  'train',
#  'baseball',
#  'player',
#  'yongguk',
#  'girl',
#  'named',
#  'jinhee',
#  'crush',
#  'passengers',
#  'manage',
#  'escape',
#  'car',
#  'news',
#  'broadcasts',
#  'report',
#  'zombie',
#  'outbreaks',
#  'country',
#  'train',
#  'stops',
#  'daejeon',
#  'surviving',
#  'passengers',
#  'city',
#  'overrun',
#  'hastily',
#  'retreat',
#  'train',
#  'splitting',
#  'different',
#  'train',
#  'cars',
#  'chaos',
#  'conductor',
#  'restarts',
#  'train',
#  'head',
#  'busan',
#  'successful',
#  'quarantine',
#  'zone',
#  'reportedly',
#  'established',
#  'seokwoo',
#  'sanghwa',
#  'yongguk',
#  'fight',
#  'way',
#  'suan',
#  'ingil',
#  'seongkyeong',
#  'hiding',
#  'struggle',
#  'zombie',
#  'horde',
#  'train',
#  'car',
#  'passengers',
#  'sheltered',
#  'instigation',
#  'yonsuk',
#  'passengers',
#  'block',
#  'survivors',
#  'entering',
#  'fearing',
#  'infected',
#  'sanghwa',
#  'ingil',
#  'sacrifice',
#  'time',
#  'force',
#  'open',
#  'door',
#  'enter',
#  'car',
#  'yonsuk',
#  'demands',
#  'newcomers',
#  'isolate',
#  'vestibule',
#  'follow',
#  'lead',
#  'jonggil',
#  'deliberately',
#  'opens',
#  'door',
#  'zombies',
#  'zombified',
#  'sister',
#  'ingil',
#  'zombies',
#  'kill',
#  'rest',
#  'passengers',
#  'leaving',
#  'seokwoo',
#  'suan',
#  'seongkyeong',
#  'safe',
#  'vestibule',
#  'yonsuk',
#  'train',
#  'attendant',
#  'escape',
#  'onslaught',
#  'hiding',
#  'bathroom',
#  'blocked',
#  'track',
#  'east',
#  'daegu',
#  'train',
#  'station',
#  'forces',
#  'survivors',
#  'stop',
#  'search',
#  'train',
#  'process',
#  'seokwoo',
#  'seongkyeong',
#  'suan',
#  'homeless',
#  'man',
#  'separated',
#  'yongguk',
#  'jinhee',
#  'yonsuk',
#  'escapes',
#  'pushing',
#  'train',
#  'attendant',
#  'killed',
#  'zombies',
#  'does',
#  'jinhee',
#  'heartbroken',
#  'yongguk',
#  'stays',
#  'jinhee',
#  'soon',
#  'bitten',
#  'train',
#  'conductor',
#  'starts',
#  'locomotive',
#  'track',
#  'killed',
#  'zombies',
#  'trying',
#  'save',
#  'yonsuk',
#  'homeless',
#  'man',
#  'sacrifices',
#  'let',
#  'suan',
#  'seongkyeong',
#  'escape',
#  'seokwoo',
#  'train',
#  'conductor',
#  'activated',
#  'encounter',
#  'yonsuk',
#  'engine',
#  'room',
#  'verge',
#  'turning',
#  'zombie',
#  'having',
#  'bitten',
#  'train',
#  'conductor',
#  'saved',
#  'seokwoo',
#  'fights',
#  'bitten',
#  'puts',
#  'suan',
#  'seongkyeong',
#  'inside',
#  'engine',
#  'room',
#  'shares',
#  'words',
#  'daughter',
#  'moving',
#  'outside',
#  'zombifies',
#  'thinks',
#  'time',
#  'held',
#  'daughter',
#  'arms',
#  'throws',
#  'locomotive',
#  'smile',
#  'suan',
#  'seongkyeong',
#  'busan',
#  'begin',
#  'walking',
#  'train',
#  'tunnel',
#  'tunnel',
#  'soldiers',
#  'stationed',
#  'defend',
#  'perimeter',
#  'zombies',
#  'unable',
#  'new',
#  'arrivals',
#  'clearly',
#  'soldiers',
#  'checkpoint',
#  'instructed',
#  'shoot',
#  'soldiers',
#  'hear',
#  'singing',
#  'makes',
#  'realize',
#  'newcomers',
#  'human',
#  'suan',
#  'tearfully',
#  'singing',
#  'song',
#  'wanted',
#  'perform',
#  'father',
#  'beginning',
#  'film',
#  'singing',
#  'honor',
#  'sacrifice']

# %%
# let's get a count of each word in the description
# a Counter does just what it sounds like.  It's a dictionary with
# the word as a key, and the count as the value.

from collections import Counter

word_counts = Counter(words_cleaned)

# %%
word_counts
# Out:
# Counter({'seokwoo': 6,
#          'divorced': 1,
#          'fund': 1,
#          'manager': 1,
#          'workaholic': 1,
#          'absentee': 1,
#          'father': 3,
#          'young': 2,
#          'daughter': 3,
#          'suan': 8,
#          'birthday': 1,
#          'day': 1,
#          'wishes': 1,
#          'busan': 3,
#          'mother': 1,
#          'board': 1,
#          'ktx': 1,
#          'seoul': 1,
#          'station': 2,
#          'train': 18,
#          'tough': 1,
#          'workingclass': 1,
#          'husband': 1,
#          'sanghwa': 3,
#          'pregnant': 1,
#          'wife': 1,
#          'seongkyeong': 7,
#          'high': 1,
#          'school': 1,
#          'baseball': 2,
#          'team': 1,
#          'richyetegotistical': 1,
#          'coo': 1,
#          'yonsuk': 7,
#          'elderly': 1,
#          'sisters': 1,
#          'ingil': 4,
#          'jongil': 1,
#          'homeless': 3,
#          'man': 3,
#          'experiencing': 1,
#          'posttraumatic': 1,
#          'stress': 1,
#          'disorder': 1,
#          'departs': 1,
#          'convulsing': 1,
#          'woman': 2,
#          'boards': 1,
#          'bite': 1,
#          'wound': 1,
#          'leg': 1,
#          'soon': 2,
#          'zombie': 5,
#          'attacks': 1,
#          'attendant': 3,
#          'turns': 1,
#          'infection': 1,
#          'quickly': 1,
#          'spreads': 1,
#          'player': 1,
#          'yongguk': 4,
#          'girl': 1,
#          'named': 1,
#          'jinhee': 4,
#          'crush': 1,
#          'passengers': 5,
#          'manage': 1,
#          'escape': 3,
#          'car': 3,
#          'news': 1,
#          'broadcasts': 1,
#          'report': 1,
#          'outbreaks': 1,
#          'country': 1,
#          'stops': 1,
#          'daejeon': 1,
#          'surviving': 1,
#          'city': 1,
#          'overrun': 1,
#          'hastily': 1,
#          'retreat': 1,
#          'splitting': 1,
#          'different': 1,
#          'cars': 1,
#          'chaos': 1,
#          'conductor': 4,
#          'restarts': 1,
#          'head': 1,
#          'successful': 1,
#          'quarantine': 1,
#          'zone': 1,
#          'reportedly': 1,
#          'established': 1,
#          'fight': 1,
#          'way': 1,
#          'hiding': 2,
#          'struggle': 1,
#          'horde': 1,
#          'sheltered': 1,
#          'instigation': 1,
#          'block': 1,
#          'survivors': 2,
#          'entering': 1,
#          'fearing': 1,
#          'infected': 1,
#          'sacrifice': 2,
#          'time': 2,
#          'force': 1,
#          'open': 1,
#          'door': 2,
#          'enter': 1,
#          'demands': 1,
#          'newcomers': 2,
#          'isolate': 1,
#          'vestibule': 2,
#          'follow': 1,
#          'lead': 1,
#          'jonggil': 1,
#          'deliberately': 1,
#          'opens': 1,
#          'zombies': 5,
#          'zombified': 1,
#          'sister': 1,
#          'kill': 1,
#          'rest': 1,
#          'leaving': 1,
#          'safe': 1,
#          'onslaught': 1,
#          'bathroom': 1,
#          'blocked': 1,
#          'track': 2,
#          'east': 1,
#          'daegu': 1,
#          'forces': 1,
#          'stop': 1,
#          'search': 1,
#          'process': 1,
#          'separated': 1,
#          'escapes': 1,
#          'pushing': 1,
#          'killed': 2,
#          'does': 1,
#          'heartbroken': 1,
#          'stays': 1,
#          'bitten': 3,
#          'starts': 1,
#          'locomotive': 2,
#          'trying': 1,
#          'save': 1,
#          'sacrifices': 1,
#          'let': 1,
#          'activated': 1,
#          'encounter': 1,
#          'engine': 2,
#          'room': 2,
#          'verge': 1,
#          'turning': 1,
#          'having': 1,
#          'saved': 1,
#          'fights': 1,
#          'puts': 1,
#          'inside': 1,
#          'shares': 1,
#          'words': 1,
#          'moving': 1,
#          'outside': 1,
#          'zombifies': 1,
#          'thinks': 1,
#          'held': 1,
#          'arms': 1,
#          'throws': 1,
#          'smile': 1,
#          'begin': 1,
#          'walking': 1,
#          'tunnel': 2,
#          'soldiers': 3,
#          'stationed': 1,
#          'defend': 1,
#          'perimeter': 1,
#          'unable': 1,
#          'new': 1,
#          'arrivals': 1,
#          'clearly': 1,
#          'checkpoint': 1,
#          'instructed': 1,
#          'shoot': 1,
#          'hear': 1,
#          'singing': 3,
#          'makes': 1,
#          'realize': 1,
#          'human': 1,
#          'tearfully': 1,
#          'song': 1,
#          'wanted': 1,
#          'perform': 1,
#          'beginning': 1,
#          'film': 1,
#          'honor': 1})

# %%
# let's find the 20 most common, and plot them
num = 20
most_common = word_counts.most_common(num)

# %%
most_common
# Out:
# [('train', 18),
#  ('suan', 8),
#  ('seongkyeong', 7),
#  ('yonsuk', 7),
#  ('seokwoo', 6),
#  ('zombie', 5),
#  ('passengers', 5),
#  ('zombies', 5),
#  ('ingil', 4),
#  ('yongguk', 4),
#  ('jinhee', 4),
#  ('conductor', 4),
#  ('father', 3),
#  ('daughter', 3),
#  ('busan', 3),
#  ('sanghwa', 3),
#  ('homeless', 3),
#  ('man', 3),
#  ('attendant', 3),
#  ('escape', 3)]

# %% [markdown]
# ### Make a bar chart of the most common words

# %%
# pre-processing
labels = [tup[0] for tup in most_common]
counts = [tup[1] for tup in most_common]
print(labels)
print(counts)
# Out:
# ['train', 'suan', 'seongkyeong', 'yonsuk', 'seokwoo', 'zombie', 'passengers', 'zombies', 'ingil', 'yongguk', 'jinhee', 'conductor', 'father', 'daughter', 'busan', 'sanghwa', 'homeless', 'man', 'attendant', 'escape']
# [18, 8, 7, 7, 6, 5, 5, 5, 4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
# use matplotlib to make a bar chart
import matplotlib.pyplot as plt

# choose a nice matplotlib style
plt.style.use('ggplot')

# %%
# change the default text size (it's usually too small)
plt.rcParams.update({'font.size': 14})

# %%
# from "A simple bar chart" in your Matplotlib.pdf cheatsheat

N = len(labels)
fig, ax = plt.subplots(figsize=(12, 6))
width = 0.8
ticklocations = list(range(N))
ax.bar(ticklocations, counts, width, linewidth=4.0, align='center')
ax.set_xticks(ticks=ticklocations)
ax.set_xticklabels(labels, rotation=90)
ax.set_xlim(min(ticklocations)-0.6, max(ticklocations)+0.6)
ax.set_yticks(range(N))
ax.set_ylim((0,N))
ax.yaxis.grid(True)
ax.set_xlabel('word')
ax.set_ylabel('counts');

# %% [markdown]
# ### Wordcloud visualization
# A wordcloud is another nice way to visualize the frequency or importance of
# words in text data. Alt-tab to your Unix/Linux terminal and install a wordcloud
# utility for Python from the command line:
# ```bash
# $ conda install -c conda-forge wordcloud
# ```

# %%
# get cleaned words into one-string for wordcloud utility
cleaned_text = ' '.join([word for word in words_cleaned])
cleaned_text[:nc]
# Out:
# 'seokwoo divorced fund manager workaholic absentee father young daughter suan birthday day wishes father busan mother board ktx seoul station train tough working'

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(background_color="white", width=960, height=960, margin=8).generate(cleaned_text)
fig, ax = plt.subplots(figsize=(8,8))
ax.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
